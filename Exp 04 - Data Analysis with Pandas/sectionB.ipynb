# %%
import pandas as pd

# %%
strudent_count_data = {
    "day_count": [1, 2, 3, 4, 5, 6],
    "is_raining": [True, False, True, False, True, False],
    "is_weekend": [False, False, True, True, False, False],
    "temperature": [30, 25, 28, 22, 27, 24],
    "students_count": [20, 30, 15, 25, 18, 22]
}

df = pd.DataFrame(strudent_count_data)

df.head(6)

# %%
df.tail(3)

# %%
# Reading data from a CSV file
path = "../datasets/titanic/titanic_full.csv"
df = pd.read_csv(path)

# %%
df.info()

# %%
df.head(5)

# %%
df[['Name', 'Age', 'Sex', 'Fare']].head(7)

# %%
df[df['Sex'] == 'female'][['Name', 'Age']].describe()

# %%
female_survived = df[(df['Sex'] ==  'female') & (df['Survived'] == 1)][['Age', 'Name']]
male_survived = df[(df['Sex'] ==  'male') & (df['Survived'] == 1)][['Age', 'Name']]

# %%
female_survived.to_csv('Survived Females List.csv')

# %%
print(f"Female survived: {female_survived[0]}")
print(f"Male survived: {male_survived[0]}")
